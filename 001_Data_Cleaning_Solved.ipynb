# %% [markdown]
# <a href="https://colab.research.google.com/github/xecon/github-upload/blob/master/001_Data_Cleaning_Solved.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# @title Login using your Workshop Account, so we can access the data
from google.colab import auth
from google.cloud import bigquery
from google.colab import data_table

project = 'ct-workshop-001' # Project ID inserted based on the query results selected to explore
location = 'EU' # Location inserted based on the query results selected to explore
client = bigquery.Client(project=project, location=location)
data_table.enable_dataframe_formatter()
auth.authenticate_user()

# %%
# %load_ext google.colab.data_table

# %%
# prompt: get data from bigquery table ct-workshop-001.workshop_datasets.dummy_data

# @title Get the data
sql = """
SELECT * FROM `ct-workshop-001.workshop_datasets.dummy_data`
"""
df = client.query(sql).to_dataframe()
df
# Out:
#          Naam  Data engineering  Data analysis  Data Science  ML Engineering  \
# 0    Person 2                 0              1             0               0
# 1   Person 14                 0              1             4               0
# 2   Person 24                 0              0             1               0
# 3    Person 7                 2              1             0               0
# 4   Person 13                 2              1             2               0
# 5   Person 15                 2              2             2               0
# 6   Person 16                 2              0             0               0
# 7    Person 5                 0              0             1               1
# 8   Person 11                 0              0             1               1
# 9   Person 12                 0              1             1               1
# 10  Person 22                 0              1             1               1
# 11   Person 3                 1              1             1               1
# 12  Person 10                 1              0             1               1
# 13  Person 17                 1              2             2               1
# 14  Person 21                 1              1             0               1
# 15  Person 23                 1              2             0               1
# 16  Person 26                 1             -1             3               1
# 17  Person 24                 1              1             0               1
# 18   Person 1                 2              1             1               1
# 19   Person 6                 2              2             2               1
# 20  Person 18                 5              2             2               1
# 21   Person 4                 1              2             0               2
# 22   Person 9                 1              4             2               2
# 23  Person 25                 1              1             0               2
# 24  Person 20                 3              3             0               2
# 25   Person 8                 1              2             1               3
# 26  Person 19                 2              0             1               3
#
#                      Role                                         Work Gender  \
# 0   IT Support Specialist                audit data access using Excel      M
# 1           Data Engineer            build predictive models in Python      F
# 2         DevOps Engineer                 visualize data in TensorFlow      M
# 3            BI Developer    deploy models to production with BigQuery      F
# 4   IT Support Specialist                      visualize data in Excel      F
# 5      Software Developer      deploy models to production with Docker      M
# 6           Data Engineer               write ETL scripts using Docker      x
# 7   IT Support Specialist              troubleshoot issues using Excel      F
# 8   IT Support Specialist                   process data with BigQuery      F
# 9                     DPO                design dashboards in BigQuery      x
# 10                    DPO      deploy models to production with Python      X
# 11        Project Manager             optimize workflows with IntelliJ      F
# 12            ML Engineer                    process data with Tableau      M
# 13  IT Support Specialist          manage data pipelines with BigQuery      X
# 14          Data Engineer                       process data with Jira      F
# 15         Data Scientist                design dashboards in BigQuery      X
# 16           I don't know                                            ?      m
# 17     Software Developer  troubleshoot issues using Jupyter Notebooks      x
# 18           BI Developer                  audit data access using DBT      F
# 19                    DPO                  audit data access using DBT      F
# 20          Data Engineer                design dashboards in IntelliJ   None
# 21        Project Manager                  write ETL scripts using AWS      M
# 22            ML Engineer                    analyze trends using Jira      X
# 23     Software Developer   troubleshoot issues using Jupyter Notebook      X
# 24        DevOps Engineer             manage data pipelines with Excel      M
# 25          Data Engineer           audit data access using SQL Server   None
# 26         Data Scientist                   process data with Collibra      F
#
#     Age
# 0    23
# 1    23
# 2    26
# 3    44
# 4    55
# 5    36
# 6    37
# 7    28
# 8    27
# 9    23
# 10   20
# 11   23
# 12   24
# 13   57
# 14   29
# 15   50
# 16   43
# 17   61
# 18   37
# 19   52
# 20   56
# 21   42
# 22   63
# 23   61
# 24   48
# 25   68
# 26   50

# %%
# prompt: Rename all columns without spaces and make them lowercase, also rename naam to name

# Rename columns
new_columns = []
for col in df.columns:
    new_col = col.replace(" ", "_").lower()
    if new_col == 'naam':
        new_col = 'name'
    new_columns.append(new_col)

df.columns = new_columns
df
# Out:
#          name  data_engineering  data_analysis  data_science  ml_engineering  \
# 0    Person 2                 0              1             0               0
# 1   Person 14                 0              1             4               0
# 2   Person 24                 0              0             1               0
# 3    Person 7                 2              1             0               0
# 4   Person 13                 2              1             2               0
# 5   Person 15                 2              2             2               0
# 6   Person 16                 2              0             0               0
# 7    Person 5                 0              0             1               1
# 8   Person 11                 0              0             1               1
# 9   Person 12                 0              1             1               1
# 10  Person 22                 0              1             1               1
# 11   Person 3                 1              1             1               1
# 12  Person 10                 1              0             1               1
# 13  Person 17                 1              2             2               1
# 14  Person 21                 1              1             0               1
# 15  Person 23                 1              2             0               1
# 16  Person 26                 1             -1             3               1
# 17  Person 24                 1              1             0               1
# 18   Person 1                 2              1             1               1
# 19   Person 6                 2              2             2               1
# 20  Person 18                 5              2             2               1
# 21   Person 4                 1              2             0               2
# 22   Person 9                 1              4             2               2
# 23  Person 25                 1              1             0               2
# 24  Person 20                 3              3             0               2
# 25   Person 8                 1              2             1               3
# 26  Person 19                 2              0             1               3
#
#                      role                                         work gender  \
# 0   IT Support Specialist                audit data access using Excel      M
# 1           Data Engineer            build predictive models in Python      F
# 2         DevOps Engineer                 visualize data in TensorFlow      M
# 3            BI Developer    deploy models to production with BigQuery      F
# 4   IT Support Specialist                      visualize data in Excel      F
# 5      Software Developer      deploy models to production with Docker      M
# 6           Data Engineer               write ETL scripts using Docker      x
# 7   IT Support Specialist              troubleshoot issues using Excel      F
# 8   IT Support Specialist                   process data with BigQuery      F
# 9                     DPO                design dashboards in BigQuery      x
# 10                    DPO      deploy models to production with Python      X
# 11        Project Manager             optimize workflows with IntelliJ      F
# 12            ML Engineer                    process data with Tableau      M
# 13  IT Support Specialist          manage data pipelines with BigQuery      X
# 14          Data Engineer                       process data with Jira      F
# 15         Data Scientist                design dashboards in BigQuery      X
# 16           I don't know                                            ?      m
# 17     Software Developer  troubleshoot issues using Jupyter Notebooks      x
# 18           BI Developer                  audit data access using DBT      F
# 19                    DPO                  audit data access using DBT      F
# 20          Data Engineer                design dashboards in IntelliJ   None
# 21        Project Manager                  write ETL scripts using AWS      M
# 22            ML Engineer                    analyze trends using Jira      X
# 23     Software Developer   troubleshoot issues using Jupyter Notebook      X
# 24        DevOps Engineer             manage data pipelines with Excel      M
# 25          Data Engineer           audit data access using SQL Server   None
# 26         Data Scientist                   process data with Collibra      F
#
#     age
# 0    23
# 1    23
# 2    26
# 3    44
# 4    55
# 5    36
# 6    37
# 7    28
# 8    27
# 9    23
# 10   20
# 11   23
# 12   24
# 13   57
# 14   29
# 15   50
# 16   43
# 17   61
# 18   37
# 19   52
# 20   56
# 21   42
# 22   63
# 23   61
# 24   48
# 25   68
# 26   50

# %% [markdown]
# # Cleaning

# %% [markdown]
# ## Names

# %%
# prompt: check if all names are unique

# Check for unique names
if len(df['name'].unique()) == len(df['name']):
    print("All names are unique.")
else:
    print("Not all names are unique.")
    duplicate_names = df[df.duplicated(subset=['name'], keep=False)]['name']
    print("Duplicate names:", duplicate_names.unique())
# Out:
# Not all names are unique.
# Duplicate names: ['Person 24']

# %%
# prompt: remove the first occurrence of the duplicate names

# Drop duplicates, keeping the first occurrence
df = df.drop_duplicates(subset=['name'], keep='first')

# Verify that there are no more duplicates
if len(df['name'].unique()) == len(df['name']):
    print("All names are now unique.")
else:
    print("There are still duplicate names.")
    duplicate_names = df[df.duplicated(subset=['name'], keep=False)]['name']
    print("Duplicate names:", duplicate_names.unique())

df
# Out:
# All names are now unique.
#          name  data_engineering  data_analysis  data_science  ml_engineering  \
# 0    Person 2                 0              1             0               0
# 1   Person 14                 0              1             4               0
# 2   Person 24                 0              0             1               0
# 3    Person 7                 2              1             0               0
# 4   Person 13                 2              1             2               0
# 5   Person 15                 2              2             2               0
# 6   Person 16                 2              0             0               0
# 7    Person 5                 0              0             1               1
# 8   Person 11                 0              0             1               1
# 9   Person 12                 0              1             1               1
# 10  Person 22                 0              1             1               1
# 11   Person 3                 1              1             1               1
# 12  Person 10                 1              0             1               1
# 13  Person 17                 1              2             2               1
# 14  Person 21                 1              1             0               1
# 15  Person 23                 1              2             0               1
# 16  Person 26                 1             -1             3               1
# 18   Person 1                 2              1             1               1
# 19   Person 6                 2              2             2               1
# 20  Person 18                 5              2             2               1
# 21   Person 4                 1              2             0               2
# 22   Person 9                 1              4             2               2
# 23  Person 25                 1              1             0               2
# 24  Person 20                 3              3             0               2
# 25   Person 8                 1              2             1               3
# 26  Person 19                 2              0             1               3
#
#                      role                                        work gender  \
# 0   IT Support Specialist               audit data access using Excel      M
# 1           Data Engineer           build predictive models in Python      F
# 2         DevOps Engineer                visualize data in TensorFlow      M
# 3            BI Developer   deploy models to production with BigQuery      F
# 4   IT Support Specialist                     visualize data in Excel      F
# 5      Software Developer     deploy models to production with Docker      M
# 6           Data Engineer              write ETL scripts using Docker      x
# 7   IT Support Specialist             troubleshoot issues using Excel      F
# 8   IT Support Specialist                  process data with BigQuery      F
# 9                     DPO               design dashboards in BigQuery      x
# 10                    DPO     deploy models to production with Python      X
# 11        Project Manager            optimize workflows with IntelliJ      F
# 12            ML Engineer                   process data with Tableau      M
# 13  IT Support Specialist         manage data pipelines with BigQuery      X
# 14          Data Engineer                      process data with Jira      F
# 15         Data Scientist               design dashboards in BigQuery      X
# 16           I don't know                                           ?      m
# 18           BI Developer                 audit data access using DBT      F
# 19                    DPO                 audit data access using DBT      F
# 20          Data Engineer               design dashboards in IntelliJ   None
# 21        Project Manager                 write ETL scripts using AWS      M
# 22            ML Engineer                   analyze trends using Jira      X
# 23     Software Developer  troubleshoot issues using Jupyter Notebook      X
# 24        DevOps Engineer            manage data pipelines with Excel      M
# 25          Data Engineer          audit data access using SQL Server   None
# 26         Data Scientist                  process data with Collibra      F
#
#     age
# 0    23
# 1    23
# 2    26
# 3    44
# 4    55
# 5    36
# 6    37
# 7    28
# 8    27
# 9    23
# 10   20
# 11   23
# 12   24
# 13   57
# 14   29
# 15   50
# 16   43
# 18   37
# 19   52
# 20   56
# 21   42
# 22   63
# 23   61
# 24   48
# 25   68
# 26   50

# %% [markdown]
# ## Gender

# %%
# prompt: capitalize the gender column, make sure values are in {X,M,F}, don't replace missing values

# Capitalize the 'gender' column
df['gender'] = df['gender'].str.upper()

# Ensure values are in {'X', 'M', 'F'}
def clean_gender(gender):
    if gender in ['X', 'M', 'F']:
        return gender
    else:
        return gender # Keep the original value if it's not in the set

df['gender'] = df['gender'].apply(clean_gender)

df
# Out:
# <ipython-input-60-526b3add58d6>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['gender'] = df['gender'].str.upper()
# <ipython-input-60-526b3add58d6>:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['gender'] = df['gender'].apply(clean_gender)
#          name  data_engineering  data_analysis  data_science  ml_engineering  \
# 0    Person 2                 0              1             0               0
# 1   Person 14                 0              1             4               0
# 2   Person 24                 0              0             1               0
# 3    Person 7                 2              1             0               0
# 4   Person 13                 2              1             2               0
# 5   Person 15                 2              2             2               0
# 6   Person 16                 2              0             0               0
# 7    Person 5                 0              0             1               1
# 8   Person 11                 0              0             1               1
# 9   Person 12                 0              1             1               1
# 10  Person 22                 0              1             1               1
# 11   Person 3                 1              1             1               1
# 12  Person 10                 1              0             1               1
# 13  Person 17                 1              2             2               1
# 14  Person 21                 1              1             0               1
# 15  Person 23                 1              2             0               1
# 16  Person 26                 1             -1             3               1
# 18   Person 1                 2              1             1               1
# 19   Person 6                 2              2             2               1
# 20  Person 18                 5              2             2               1
# 21   Person 4                 1              2             0               2
# 22   Person 9                 1              4             2               2
# 23  Person 25                 1              1             0               2
# 24  Person 20                 3              3             0               2
# 25   Person 8                 1              2             1               3
# 26  Person 19                 2              0             1               3
#
#                      role                                        work gender  \
# 0   IT Support Specialist               audit data access using Excel      M
# 1           Data Engineer           build predictive models in Python      F
# 2         DevOps Engineer                visualize data in TensorFlow      M
# 3            BI Developer   deploy models to production with BigQuery      F
# 4   IT Support Specialist                     visualize data in Excel      F
# 5      Software Developer     deploy models to production with Docker      M
# 6           Data Engineer              write ETL scripts using Docker      X
# 7   IT Support Specialist             troubleshoot issues using Excel      F
# 8   IT Support Specialist                  process data with BigQuery      F
# 9                     DPO               design dashboards in BigQuery      X
# 10                    DPO     deploy models to production with Python      X
# 11        Project Manager            optimize workflows with IntelliJ      F
# 12            ML Engineer                   process data with Tableau      M
# 13  IT Support Specialist         manage data pipelines with BigQuery      X
# 14          Data Engineer                      process data with Jira      F
# 15         Data Scientist               design dashboards in BigQuery      X
# 16           I don't know                                           ?      M
# 18           BI Developer                 audit data access using DBT      F
# 19                    DPO                 audit data access using DBT      F
# 20          Data Engineer               design dashboards in IntelliJ   None
# 21        Project Manager                 write ETL scripts using AWS      M
# 22            ML Engineer                   analyze trends using Jira      X
# 23     Software Developer  troubleshoot issues using Jupyter Notebook      X
# 24        DevOps Engineer            manage data pipelines with Excel      M
# 25          Data Engineer          audit data access using SQL Server   None
# 26         Data Scientist                  process data with Collibra      F
#
#     age
# 0    23
# 1    23
# 2    26
# 3    44
# 4    55
# 5    36
# 6    37
# 7    28
# 8    27
# 9    23
# 10   20
# 11   23
# 12   24
# 13   57
# 14   29
# 15   50
# 16   43
# 18   37
# 19   52
# 20   56
# 21   42
# 22   63
# 23   61
# 24   48
# 25   68
# 26   50

# %%
# prompt: replace missing values in the gender column with x

# Replace missing values in the 'gender' column with 'X'
df['gender'] = df['gender'].fillna('X')

df
# Out:
# <ipython-input-61-ee57ea056500>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['gender'] = df['gender'].fillna('X')
#          name  data_engineering  data_analysis  data_science  ml_engineering  \
# 0    Person 2                 0              1             0               0
# 1   Person 14                 0              1             4               0
# 2   Person 24                 0              0             1               0
# 3    Person 7                 2              1             0               0
# 4   Person 13                 2              1             2               0
# 5   Person 15                 2              2             2               0
# 6   Person 16                 2              0             0               0
# 7    Person 5                 0              0             1               1
# 8   Person 11                 0              0             1               1
# 9   Person 12                 0              1             1               1
# 10  Person 22                 0              1             1               1
# 11   Person 3                 1              1             1               1
# 12  Person 10                 1              0             1               1
# 13  Person 17                 1              2             2               1
# 14  Person 21                 1              1             0               1
# 15  Person 23                 1              2             0               1
# 16  Person 26                 1             -1             3               1
# 18   Person 1                 2              1             1               1
# 19   Person 6                 2              2             2               1
# 20  Person 18                 5              2             2               1
# 21   Person 4                 1              2             0               2
# 22   Person 9                 1              4             2               2
# 23  Person 25                 1              1             0               2
# 24  Person 20                 3              3             0               2
# 25   Person 8                 1              2             1               3
# 26  Person 19                 2              0             1               3
#
#                      role                                        work gender  \
# 0   IT Support Specialist               audit data access using Excel      M
# 1           Data Engineer           build predictive models in Python      F
# 2         DevOps Engineer                visualize data in TensorFlow      M
# 3            BI Developer   deploy models to production with BigQuery      F
# 4   IT Support Specialist                     visualize data in Excel      F
# 5      Software Developer     deploy models to production with Docker      M
# 6           Data Engineer              write ETL scripts using Docker      X
# 7   IT Support Specialist             troubleshoot issues using Excel      F
# 8   IT Support Specialist                  process data with BigQuery      F
# 9                     DPO               design dashboards in BigQuery      X
# 10                    DPO     deploy models to production with Python      X
# 11        Project Manager            optimize workflows with IntelliJ      F
# 12            ML Engineer                   process data with Tableau      M
# 13  IT Support Specialist         manage data pipelines with BigQuery      X
# 14          Data Engineer                      process data with Jira      F
# 15         Data Scientist               design dashboards in BigQuery      X
# 16           I don't know                                           ?      M
# 18           BI Developer                 audit data access using DBT      F
# 19                    DPO                 audit data access using DBT      F
# 20          Data Engineer               design dashboards in IntelliJ      X
# 21        Project Manager                 write ETL scripts using AWS      M
# 22            ML Engineer                   analyze trends using Jira      X
# 23     Software Developer  troubleshoot issues using Jupyter Notebook      X
# 24        DevOps Engineer            manage data pipelines with Excel      M
# 25          Data Engineer          audit data access using SQL Server      X
# 26         Data Scientist                  process data with Collibra      F
#
#     age
# 0    23
# 1    23
# 2    26
# 3    44
# 4    55
# 5    36
# 6    37
# 7    28
# 8    27
# 9    23
# 10   20
# 11   23
# 12   24
# 13   57
# 14   29
# 15   50
# 16   43
# 18   37
# 19   52
# 20   56
# 21   42
# 22   63
# 23   61
# 24   48
# 25   68
# 26   50

# %% [markdown]
# ## Scores

# %%
# prompt: Check that all scores in columns data_engineering	data_analysis	data_science	ml_engineering are between [0,3], print names that violate

import pandas as pd

# Assuming 'df' is your DataFrame from the previous code

def check_scores(df):
    """
    Checks if scores in specified columns are within the range [0, 3].

    Args:
        df: The input DataFrame.

    Returns:
        A DataFrame with names that violate the score constraint.
    """
    cols_to_check = ['data_engineering', 'data_analysis', 'data_science', 'ml_engineering']
    violations = []
    for index, row in df.iterrows():
        for col in cols_to_check:
            if not (0 <= row[col] <= 3):
                violations.append({'name': row['name'], 'column': col, 'score': row[col]})
    return pd.DataFrame(violations)

violations_df = check_scores(df)

if violations_df.empty:
    print("All scores are within the valid range [0, 3].")
else:
    print("The following names violate the score constraint:")
violations_df
# Out:
# The following names violate the score constraint:
#         name            column  score
# 0  Person 14      data_science      4
# 1  Person 26     data_analysis     -1
# 2  Person 18  data_engineering      5
# 3   Person 9     data_analysis      4

# %%
# prompt: Fix the violations of scores in data_engineering	data_analysis	data_science	ml_engineering, by bringing them to the min or max allowed value in [0,3]

# Assuming 'df' is your DataFrame from the previous code

def fix_scores(df):
    """
    Fixes scores in specified columns by bringing them to the min or max allowed value in [0, 3].

    Args:
        df: The input DataFrame.

    Returns:
        A DataFrame with fixed scores.
    """
    cols_to_check = ['data_engineering', 'data_analysis', 'data_science', 'ml_engineering']
    for index, row in df.iterrows():
        for col in cols_to_check:
            if row[col] < 0:
                df.loc[index, col] = 0
            elif row[col] > 3:
                df.loc[index, col] = 3
    return df

df = fix_scores(df)

# Verify that all scores are within the valid range
violations_df = check_scores(df)

if violations_df.empty:
    print("All scores are now within the valid range [0, 3].")
else:
    print("There are still scores outside the valid range:")
    print(violations_df)
df
# Out:
# All scores are now within the valid range [0, 3].
#          name  data_engineering  data_analysis  data_science  ml_engineering  \
# 0    Person 2                 0              1             0               0
# 1   Person 14                 0              1             3               0
# 2   Person 24                 0              0             1               0
# 3    Person 7                 2              1             0               0
# 4   Person 13                 2              1             2               0
# 5   Person 15                 2              2             2               0
# 6   Person 16                 2              0             0               0
# 7    Person 5                 0              0             1               1
# 8   Person 11                 0              0             1               1
# 9   Person 12                 0              1             1               1
# 10  Person 22                 0              1             1               1
# 11   Person 3                 1              1             1               1
# 12  Person 10                 1              0             1               1
# 13  Person 17                 1              2             2               1
# 14  Person 21                 1              1             0               1
# 15  Person 23                 1              2             0               1
# 16  Person 26                 1              0             3               1
# 18   Person 1                 2              1             1               1
# 19   Person 6                 2              2             2               1
# 20  Person 18                 3              2             2               1
# 21   Person 4                 1              2             0               2
# 22   Person 9                 1              3             2               2
# 23  Person 25                 1              1             0               2
# 24  Person 20                 3              3             0               2
# 25   Person 8                 1              2             1               3
# 26  Person 19                 2              0             1               3
#
#                      role                                        work gender  \
# 0   IT Support Specialist               audit data access using Excel      M
# 1           Data Engineer           build predictive models in Python      F
# 2         DevOps Engineer                visualize data in TensorFlow      M
# 3            BI Developer   deploy models to production with BigQuery      F
# 4   IT Support Specialist                     visualize data in Excel      F
# 5      Software Developer     deploy models to production with Docker      M
# 6           Data Engineer              write ETL scripts using Docker      X
# 7   IT Support Specialist             troubleshoot issues using Excel      F
# 8   IT Support Specialist                  process data with BigQuery      F
# 9                     DPO               design dashboards in BigQuery      X
# 10                    DPO     deploy models to production with Python      X
# 11        Project Manager            optimize workflows with IntelliJ      F
# 12            ML Engineer                   process data with Tableau      M
# 13  IT Support Specialist         manage data pipelines with BigQuery      X
# 14          Data Engineer                      process data with Jira      F
# 15         Data Scientist               design dashboards in BigQuery      X
# 16           I don't know                                           ?      M
# 18           BI Developer                 audit data access using DBT      F
# 19                    DPO                 audit data access using DBT      F
# 20          Data Engineer               design dashboards in IntelliJ      X
# 21        Project Manager                 write ETL scripts using AWS      M
# 22            ML Engineer                   analyze trends using Jira      X
# 23     Software Developer  troubleshoot issues using Jupyter Notebook      X
# 24        DevOps Engineer            manage data pipelines with Excel      M
# 25          Data Engineer          audit data access using SQL Server      X
# 26         Data Scientist                  process data with Collibra      F
#
#     age
# 0    23
# 1    23
# 2    26
# 3    44
# 4    55
# 5    36
# 6    37
# 7    28
# 8    27
# 9    23
# 10   20
# 11   23
# 12   24
# 13   57
# 14   29
# 15   50
# 16   43
# 18   37
# 19   52
# 20   56
# 21   42
# 22   63
# 23   61
# 24   48
# 25   68
# 26   50

# %% [markdown]
# ## Name columns

# %%
# prompt: split the name column into First name and Last name, by splitting on the last space

# Split the 'name' column into 'first_name' and 'last_name'
df[['first_name', 'last_name']] = df['name'].str.rsplit(' ', n=1, expand=True)

df
# Out:
# <ipython-input-64-ae20a0625ef3>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[['first_name', 'last_name']] = df['name'].str.rsplit(' ', n=1, expand=True)
# <ipython-input-64-ae20a0625ef3>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[['first_name', 'last_name']] = df['name'].str.rsplit(' ', n=1, expand=True)
#          name  data_engineering  data_analysis  data_science  ml_engineering  \
# 0    Person 2                 0              1             0               0
# 1   Person 14                 0              1             3               0
# 2   Person 24                 0              0             1               0
# 3    Person 7                 2              1             0               0
# 4   Person 13                 2              1             2               0
# 5   Person 15                 2              2             2               0
# 6   Person 16                 2              0             0               0
# 7    Person 5                 0              0             1               1
# 8   Person 11                 0              0             1               1
# 9   Person 12                 0              1             1               1
# 10  Person 22                 0              1             1               1
# 11   Person 3                 1              1             1               1
# 12  Person 10                 1              0             1               1
# 13  Person 17                 1              2             2               1
# 14  Person 21                 1              1             0               1
# 15  Person 23                 1              2             0               1
# 16  Person 26                 1              0             3               1
# 18   Person 1                 2              1             1               1
# 19   Person 6                 2              2             2               1
# 20  Person 18                 3              2             2               1
# 21   Person 4                 1              2             0               2
# 22   Person 9                 1              3             2               2
# 23  Person 25                 1              1             0               2
# 24  Person 20                 3              3             0               2
# 25   Person 8                 1              2             1               3
# 26  Person 19                 2              0             1               3
#
#                      role                                        work gender  \
# 0   IT Support Specialist               audit data access using Excel      M
# 1           Data Engineer           build predictive models in Python      F
# 2         DevOps Engineer                visualize data in TensorFlow      M
# 3            BI Developer   deploy models to production with BigQuery      F
# 4   IT Support Specialist                     visualize data in Excel      F
# 5      Software Developer     deploy models to production with Docker      M
# 6           Data Engineer              write ETL scripts using Docker      X
# 7   IT Support Specialist             troubleshoot issues using Excel      F
# 8   IT Support Specialist                  process data with BigQuery      F
# 9                     DPO               design dashboards in BigQuery      X
# 10                    DPO     deploy models to production with Python      X
# 11        Project Manager            optimize workflows with IntelliJ      F
# 12            ML Engineer                   process data with Tableau      M
# 13  IT Support Specialist         manage data pipelines with BigQuery      X
# 14          Data Engineer                      process data with Jira      F
# 15         Data Scientist               design dashboards in BigQuery      X
# 16           I don't know                                           ?      M
# 18           BI Developer                 audit data access using DBT      F
# 19                    DPO                 audit data access using DBT      F
# 20          Data Engineer               design dashboards in IntelliJ      X
# 21        Project Manager                 write ETL scripts using AWS      M
# 22            ML Engineer                   analyze trends using Jira      X
# 23     Software Developer  troubleshoot issues using Jupyter Notebook      X
# 24        DevOps Engineer            manage data pipelines with Excel      M
# 25          Data Engineer          audit data access using SQL Server      X
# 26         Data Scientist                  process data with Collibra      F
#
#     age first_name last_name
# 0    23     Person         2
# 1    23     Person        14
# 2    26     Person        24
# 3    44     Person         7
# 4    55     Person        13
# 5    36     Person        15
# 6    37     Person        16
# 7    28     Person         5
# 8    27     Person        11
# 9    23     Person        12
# 10   20     Person        22
# 11   23     Person         3
# 12   24     Person        10
# 13   57     Person        17
# 14   29     Person        21
# 15   50     Person        23
# 16   43     Person        26
# 18   37     Person         1
# 19   52     Person         6
# 20   56     Person        18
# 21   42     Person         4
# 22   63     Person         9
# 23   61     Person        25
# 24   48     Person        20
# 25   68     Person         8
# 26   50     Person        19

# %%
# prompt: Remove the name column and introduce put the first and last name columns in front

# Move 'first_name' and 'last_name' columns to the front
cols = ['first_name', 'last_name'] + [col for col in df.columns if col not in ['name', 'first_name', 'last_name']]
df = df[cols]

df
# Out:
#    first_name last_name  data_engineering  data_analysis  data_science  \
# 0      Person         2                 0              1             0
# 1      Person        14                 0              1             3
# 2      Person        24                 0              0             1
# 3      Person         7                 2              1             0
# 4      Person        13                 2              1             2
# 5      Person        15                 2              2             2
# 6      Person        16                 2              0             0
# 7      Person         5                 0              0             1
# 8      Person        11                 0              0             1
# 9      Person        12                 0              1             1
# 10     Person        22                 0              1             1
# 11     Person         3                 1              1             1
# 12     Person        10                 1              0             1
# 13     Person        17                 1              2             2
# 14     Person        21                 1              1             0
# 15     Person        23                 1              2             0
# 16     Person        26                 1              0             3
# 18     Person         1                 2              1             1
# 19     Person         6                 2              2             2
# 20     Person        18                 3              2             2
# 21     Person         4                 1              2             0
# 22     Person         9                 1              3             2
# 23     Person        25                 1              1             0
# 24     Person        20                 3              3             0
# 25     Person         8                 1              2             1
# 26     Person        19                 2              0             1
#
#     ml_engineering                   role  \
# 0                0  IT Support Specialist
# 1                0          Data Engineer
# 2                0        DevOps Engineer
# 3                0           BI Developer
# 4                0  IT Support Specialist
# 5                0     Software Developer
# 6                0          Data Engineer
# 7                1  IT Support Specialist
# 8                1  IT Support Specialist
# 9                1                    DPO
# 10               1                    DPO
# 11               1        Project Manager
# 12               1            ML Engineer
# 13               1  IT Support Specialist
# 14               1          Data Engineer
# 15               1         Data Scientist
# 16               1           I don't know
# 18               1           BI Developer
# 19               1                    DPO
# 20               1          Data Engineer
# 21               2        Project Manager
# 22               2            ML Engineer
# 23               2     Software Developer
# 24               2        DevOps Engineer
# 25               3          Data Engineer
# 26               3         Data Scientist
#
#                                           work gender  age
# 0                audit data access using Excel      M   23
# 1            build predictive models in Python      F   23
# 2                 visualize data in TensorFlow      M   26
# 3    deploy models to production with BigQuery      F   44
# 4                      visualize data in Excel      F   55
# 5      deploy models to production with Docker      M   36
# 6               write ETL scripts using Docker      X   37
# 7              troubleshoot issues using Excel      F   28
# 8                   process data with BigQuery      F   27
# 9                design dashboards in BigQuery      X   23
# 10     deploy models to production with Python      X   20
# 11            optimize workflows with IntelliJ      F   23
# 12                   process data with Tableau      M   24
# 13         manage data pipelines with BigQuery      X   57
# 14                      process data with Jira      F   29
# 15               design dashboards in BigQuery      X   50
# 16                                           ?      M   43
# 18                 audit data access using DBT      F   37
# 19                 audit data access using DBT      F   52
# 20               design dashboards in IntelliJ      X   56
# 21                 write ETL scripts using AWS      M   42
# 22                   analyze trends using Jira      X   63
# 23  troubleshoot issues using Jupyter Notebook      X   61
# 24            manage data pipelines with Excel      M   48
# 25          audit data access using SQL Server      X   68
# 26                  process data with Collibra      F   50

# %% [markdown]
# ## Add a new column

# %%
# prompt: add a total_skill column that sums up data_engineering	data_analysis	data_science	ml_engineering

# Calculate the total skill score
df['total_skill'] = df['data_engineering'] + df['data_analysis'] + df['data_science'] + df['ml_engineering']

df
# Out:
#    first_name last_name  data_engineering  data_analysis  data_science  \
# 0      Person         2                 0              1             0
# 1      Person        14                 0              1             3
# 2      Person        24                 0              0             1
# 3      Person         7                 2              1             0
# 4      Person        13                 2              1             2
# 5      Person        15                 2              2             2
# 6      Person        16                 2              0             0
# 7      Person         5                 0              0             1
# 8      Person        11                 0              0             1
# 9      Person        12                 0              1             1
# 10     Person        22                 0              1             1
# 11     Person         3                 1              1             1
# 12     Person        10                 1              0             1
# 13     Person        17                 1              2             2
# 14     Person        21                 1              1             0
# 15     Person        23                 1              2             0
# 16     Person        26                 1              0             3
# 18     Person         1                 2              1             1
# 19     Person         6                 2              2             2
# 20     Person        18                 3              2             2
# 21     Person         4                 1              2             0
# 22     Person         9                 1              3             2
# 23     Person        25                 1              1             0
# 24     Person        20                 3              3             0
# 25     Person         8                 1              2             1
# 26     Person        19                 2              0             1
#
#     ml_engineering                   role  \
# 0                0  IT Support Specialist
# 1                0          Data Engineer
# 2                0        DevOps Engineer
# 3                0           BI Developer
# 4                0  IT Support Specialist
# 5                0     Software Developer
# 6                0          Data Engineer
# 7                1  IT Support Specialist
# 8                1  IT Support Specialist
# 9                1                    DPO
# 10               1                    DPO
# 11               1        Project Manager
# 12               1            ML Engineer
# 13               1  IT Support Specialist
# 14               1          Data Engineer
# 15               1         Data Scientist
# 16               1           I don't know
# 18               1           BI Developer
# 19               1                    DPO
# 20               1          Data Engineer
# 21               2        Project Manager
# 22               2            ML Engineer
# 23               2     Software Developer
# 24               2        DevOps Engineer
# 25               3          Data Engineer
# 26               3         Data Scientist
#
#                                           work gender  age  total_skill
# 0                audit data access using Excel      M   23            1
# 1            build predictive models in Python      F   23            4
# 2                 visualize data in TensorFlow      M   26            1
# 3    deploy models to production with BigQuery      F   44            3
# 4                      visualize data in Excel      F   55            5
# 5      deploy models to production with Docker      M   36            6
# 6               write ETL scripts using Docker      X   37            2
# 7              troubleshoot issues using Excel      F   28            2
# 8                   process data with BigQuery      F   27            2
# 9                design dashboards in BigQuery      X   23            3
# 10     deploy models to production with Python      X   20            3
# 11            optimize workflows with IntelliJ      F   23            4
# 12                   process data with Tableau      M   24            3
# 13         manage data pipelines with BigQuery      X   57            6
# 14                      process data with Jira      F   29            3
# 15               design dashboards in BigQuery      X   50            4
# 16                                           ?      M   43            5
# 18                 audit data access using DBT      F   37            5
# 19                 audit data access using DBT      F   52            7
# 20               design dashboards in IntelliJ      X   56            8
# 21                 write ETL scripts using AWS      M   42            5
# 22                   analyze trends using Jira      X   63            8
# 23  troubleshoot issues using Jupyter Notebook      X   61            4
# 24            manage data pipelines with Excel      M   48            8
# 25          audit data access using SQL Server      X   68            7
# 26                  process data with Collibra      F   50            6

# %% [markdown]
# # Storing

# %%
# prompt: Store the result in Bigquery in table ct-workshop-001.workshop_datasets.dummy_data_clean_ suffixed with today's date

from datetime import date

today = date.today().strftime("%Y%m%d")
# table_id = f"ct-workshop-001.workshop_datasets.dummy_data_clean_{today}"
usernr = 46 # @param {type:"integer"}
table_id = f"ct-workshop-001.workshop_workspace{usernr}.dummy_data_clean_{today}"

job_config = bigquery.LoadJobConfig(write_disposition="WRITE_TRUNCATE")

job = client.load_table_from_dataframe(
    df, table_id, job_config=job_config
)
job.result()  # Wait for the job to complete.

table = client.get_table(table_id)
print(
    "Loaded {} rows and {} columns to {}".format(
        table.num_rows, len(table.schema), table_id
    )
)
# Out:
#   File "<ipython-input-1-43c9e017b33d>", line 7
#     usernr = 46 @param {type:"integer"}
#                        ^
# SyntaxError: invalid syntax
